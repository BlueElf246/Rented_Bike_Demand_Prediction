# %% [markdown]
# <center>
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0321EN-SkillsNetwork/labs/module_1/images/SN_web_lightmode.png" width="300">
# </center>

# %% [markdown]
# <h1>Web scrape a Global Bike-Sharing Systems Wiki Page</h1>
#
# Estimated time needed: **20** minutes

# %% [markdown]
# ## Lab Overview:
#
# Before getting your hands dirty on the actual data analysis tasks, you first need to obtain some background and context information about well-known bike sharing systems worldwide, such as their location, launch date, rental bike size, and so on.
#
# You can get such information from this Wiki page:
#
# https://en.wikipedia.org/wiki/List_of_bicycle-sharing_systems
#
# <a href="https://cognitiveclass.ai/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork878-2022-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0321EN-SkillsNetwork/labs/module_1/images/l2-list-bike-sharing-systems.png" width="600" align="center">
# </a>

# %% [markdown]
# First import necessary libraries for the webscraping task.

# %% [markdown]
# In this lab, you need to use the `rvest` library to obtain the bike sharing systems table from the above web page, convert the table into a data frame, and write the data frame to a csv file for future data wrangling and analysis tasks.

# %%
# Check if need to install rvest` library
require("rvest")

library(rvest)
# Out:
# Loading required package: rvest

# %% [markdown]
# # TASK: Extract bike sharing systems HTML table from a Wiki page and convert it into a data frame

# %% [markdown]
# _TODO:_ Get the root HTML node

# %%
url <- "https://en.wikipedia.org/wiki/List_of_bicycle-sharing_systems"
# Get the root HTML node by calling the `read_html()` method with URL
root = read_html(url)
tables = html_nodes(root, 'table')
tables
# Out:
# {xml_nodeset (4)}
# [1] <table class="wikitable sortable" style="text-align:left"><tbody>\n<tr>\n ...
# [2] <table class="nowraplinks mw-collapsible autocollapse navbox-inner" style ...
# [3] <table class="nowraplinks navbox-subgroup" style="border-spacing:0"><tbod ...
# [4] <table class="nowraplinks navbox-subgroup" style="border-spacing:0"><tbod ...

# %% [markdown]
# Note that this HTML page at least contains three child `<table>` nodes under the root HTML node. So, you will need to use `html_nodes(root_node, "table")` function to get all its child `<table>` nodes:
#
# ```
# <html>
#   <table>(table1)</table>
#   <table>(table2)</table>
#   <table>(table3)</table>
#   ...
# </html>
# ```

# %% [markdown]
# table_nodes <- html_nodes(root_node, "table")

# %% [markdown]
# You can use a `for` loop to print each table, and then you will see that the actual the bike sharing table is the first element `table_nodes[[1]]`.

# %% [markdown]
# Next, you need to convert this HTML table into a data frame using the `html_table()` function. You may choose to include `fill = TRUE` argument to fill any empty table rows/columns.

# %%
# Convert the bike-sharing system table into a dataframe
df = html_table(tables[[1]], fill=TRUE)
df
# Out:
#     Country
# 1   Albania
# 2   Argentina
# 3   Argentina
# 4   Argentina
# 5   Argentina
# 6   Australia
# 7   Australia
# 8   Australia
# 9   Australia
# 10  Australia
# 11  Australia
# 12  Austria
# 13  Austria
# 14  Austria
# 15  Austria
# 16  Austria
# 17  Austria
# 18  Bangladesh
# 19  Belgium
# 20  Belgium
# 21  Belgium
# 22  Belgium
# 23  Bosnia and Herzegovina[citation needed]
# 24  Bosnia and Herzegovina[citation needed]
# 25  Bosnia and Herzegovina[citation needed]
# 26  Bosnia and Herzegovina[citation needed]
# 27  Bosnia and Herzegovina[citation needed]
# 28  Brazil
# 29  Brazil
# 30  Brazil
# ⋮   ⋮
# 525 United States
# 526 United States
# 527 United States
# 528 United States
# 529 United States
# 530 United States
# 531 United States
# 532 United States
# 533 United States
# 534 United States
# 535 United States
# 536 United States
# 537 United States
# 538 United States
# 539 United States
# 540 United States
# 541 United States
# 542 United States
# 543 United States
# 544 United States
# 545 United States
# 546 United States
# 547 United States
# 548 United States
# 549 United States
# 550 United States
# 551 United States
# 552 United States
# 553 United States
# 554 United States
#     City                                          Name
# 1   Tirana[5]                                     Ecovolis
# 2   Buenos Aires[6][7]                            Ecobici
# 3   Mendoza[10]                                   Metrobici
# 4   Rosario                                       Mi Bici Tu Bici[11]
# 5   San Lorenzo, Santa Fe                         Biciudad
# 6   Melbourne[12]                                 Melbourne Bike Share
# 7   Melbourne[12]                                 oBike
# 8   Brisbane[14][15]                              CityCycle
# 9   Sydney                                        oBike
# 10  Sydney                                        Ofo
# 11  Sydney                                        Reddy Go
# 12  Burgenland                                    LEIHRADL nextbike
# 13  Lower Austria[16]                             LEIHRADL nextbike
# 14  Salzburg                                      nextbike
# 15  Vienna                                        Citybike Wien[17]
# 16  Vienna                                        Viennabike
# 17  Vorarlberg
# 18  Dhaka                                         JoBike
# 19  Different locations[19]                       dBlue-bike
# 20  Antwerp                                       Velo Antwerp[22]
# 21  Brussels[24]                                  Villo!
# 22  Namur[26]                                     Libiavelo
# 23  Banja Luka                                    BL bike
# 24  Mostar                                        nextbike
# 25  Sarajevo                                      nextbike
# 26  Tuzla                                         nextbike
# 27  Zenica                                        nextbike
# 28  Belo Horizonte[27]                            Bikebh
# 29  Fortaleza                                     Bicicletar
# 30  João Pessoa[28]                               SAMBA
# ⋮   ⋮                                             ⋮
# 525 Kona District, Hawaii
# 526 Lansing, Michigan                             Capital Community Bikeshare
# 527 Lincoln, Nebraska[335]                        BikeLNK
# 528 Los Angeles                                   Metro Bike Share
# 529 Madison, Wisconsin[336]                       Madison B-Cycle
# 530 Meridian, Colorado                            M-Bike
# 531 Miami Beach, Florida[337]                     Decobike
# 532 Milwaukee[338][339]                           Bublr Bikes
# 533 Minneapolis–Saint Paul[340][341]              Nice Ride Minnesota
# 534 New York City[343][344][345][346][347]        Citi Bike
# 535 Oklahoma City[348]                            Spokies
# 536 Omaha, Nebraska[349]                          Omaha B-Cycle
# 537 Philadelphia[350][351]                        Indego
# 538 Phoenix, Arizona                              Grid Bike Share
# 539 Pittsburgh                                    POGOH
# 540 Portland, Oregon                              Biketown
# 541 Portland, Oregon                              Yellow Bike Project
# 542 Salt Lake City[354]                           SLC Bike Share
# 543 San Antonio[355]                              San Antonio B-Cycle
# 544 San Diego[356]                                DecoBike
# 545 San Francisco Bay Area
# 546 San Francisco Bay Area                        Baywheels
# 547 Santa Monica, California[357]                 Breeze Bike Share
# 548 Savannah, Georgia[358]                        CAT Bike
# 549 Seattle[359]                                  Pronto Cycle Share
# 550 Spartanburg, South Carolina[360]              Spartanburg B-Cycle
# 551 St. Paul                                      Yellow Bike Project
# 552 Springfield, Massachusetts and Pioneer Valley ValleyBike Share
# 553 Tampa, Florida[365]                           Coast Bike Share
# 554 Washington metropolitan area[366]             Capital Bikeshare
#     System
# 1
# 2   Serttel Brasil[8]
# 3
# 4
# 5   Biciudad
# 6   PBSC & 8D
# 7   4 Gen. oBike
# 8   3 Gen. Cyclocity
# 9   4 Gen. oBike
# 10  4 Gen. Ofo
# 11  Reddy Go
# 12  3 Gen. nextbike
# 13  3 Gen. nextbike
# 14  3 Gen. nextbike
# 15  3 Gen. Cyclocity
# 16  2 Gen.
# 17  3 Gen. nextbike
# 18  JoBike
# 19  Blue-bike
# 20  3 Gen. Clear CC
# 21  3 Gen. Cyclocity
# 22  3 Gen. Cyclocity
# 23  3 Gen.\nnextbike
# 24  3 Gen.\nnextbike
# 25  3 Gen.\nnextbike
# 26  3 Gen.\nnextbike
# 27  3 Gen.\nnextbike
# 28  Mobilicidade
# 29  Mobilicidade
# 30  Mobilicidade
# ⋮   ⋮
# 525 PBSC
# 526 A2B Bikeshare
# 527 3 Gen. B-Cycle
# 528 3 Gen. B-Cycle
# 529 3 Gen. B-Cycle
# 530 Zagster
# 531 SandVault
# 532 3 Gen. B-Cycle
# 533 PBSC & 8D
# 534 PBSC & 8D
# 535 Spokies
# 536 3 Gen. B-Cycle
# 537 3 Gen. B-Cycle (incl. some e-bikes
# 538 3 Gen. CycleHop and Social Bicycles
# 539 3 Gen. nextbike
# 540
# 541 1 Gen. WhiteBikes
# 542 3 Gen. B-Cycle
# 543 3 Gen. B-Cycle
# 544 DecoBike
# 545
# 546 8D
# 547 3 Gen. CycleHop and Social Bicycles
# 548 3 Gen. B-Cycle
# 549 8D
# 550 3 Gen. B-Cycle
# 551 1 Gen. w/ BikeCard
# 552
# 553 3 Gen. CycleHop and Social Bicycles
# 554 PBSC & 8D
#     Operator
# 1
# 2   Bike In Baires Consortium[9]
# 3
# 4
# 5
# 6   Motivate
# 7
# 8   JCDecaux
# 9
# 10
# 11
# 12
# 13
# 14
# 15  JCDecaux Gewista
# 16  Association and city council
# 17
# 18
# 19  Blue-Mobility
# 20  Service2Cities (subsidiary of Clear Channel Belgium)
# 21  JCDecaux
# 22  JCDecaux
# 23  nextbike
# 24
# 25
# 26
# 27
# 28
# 29
# 30
# ⋮   ⋮
# 525
# 526
# 527
# 528
# 529
# 530
# 531
# 532
# 533
# 534 Motivate
# 535
# 536
# 537
# 538
# 539
# 540
# 541 Yellow Bike Project
# 542
# 543
# 544 JCDecaux
# 545
# 546 Motivate
# 547
# 548
# 549 Motivate
# 550
# 551 volunteers and city council
# 552 Begwegen Technologies[361]
# 553
# 554 Motivate
#     Launched                                Discontinued          Stations
# 1   March 2011                                                    8
# 2   2010                                                          400
# 3   2014                                                          2
# 4   2 December 2015                                               47
# 5   27 November 2016                                              8
# 6   June 2010                               30 November 2019[13]  53
# 7   July 2017                               July 2018             dockless
# 8   September 2010                                                150
# 9   July 2017                               July 2018             dockless
# 10  October 2017                                                  dockless
# 11  July 2017
# 12  2009                                                          40
# 13  2009                                                          295
# 14  2011
# 15  June 2003                                                     121
# 16  April 2002                              November 2002         200
# 17  2009                                                          14
# 18  2018                                                          05
# 19  1 May 2011                                                    70 (2021)[20]
# 20  9 June 2011                                                   305 (2021)
# 21  19 May 2009 (earlier system since 2006)                       346
# 22  21 April 2012                                                 24
# 23  3 April 2018                                                  5
# 24  26 March 2023                                                 10
# 25  1 June 2016                                                   20
# 26  14 July 2017                            1 May 2019            3
# 27  11 October 2019                                               15
# 28  2014                                                          40
# 29  15 December 2014                                              80
# 30                                                                3
# ⋮   ⋮                                       ⋮                     ⋮
# 525 2016                                                          3
# 526 2014                                                          8
# 527 2018                                                          19
# 528 7 July 2016                                                   207
# 529 2011                                                          39
# 530 15 March 2010                                                 11
# 531 2011                                                          100
# 532 2014                                                          87
# 533 2010                                    13 November 2022[342] 171
# 534 27 May 2013                                                   739
# 535 2012                                                          7
# 536 2011                                                          5
# 537 23 April 2015                                                 125
# 538 25 November 2014                                              40
# 539 2015                                                          50
# 540 19 July 2016                                                  100
# 541 1994[352]                               1997[353]
# 542 2013                                                          12
# 543 2011                                                          68
# 544 February 2015                                                 180
# 545 2013
# 546 June 2017                                                     550
# 547 13 August 2015                                                80
# 548 24 January 2014                                               2
# 549 13 October 2014                         31 March 2017         50
# 550 2011                                                          5
# 551 1997
# 552 June 28, 2018[362]                                            61[363]
# 553 7 December 2014                                               30
# 554 2010                                                          658
#     Bicycles        Daily ridership
# 1   200
# 2   4000            21917
# 3   40
# 4   480
# 5   80
# 6   676
# 7   1250
# 8   2000
# 9   1250
# 10  600
# 11  2000
# 12
# 13  1300
# 14
# 15  1500            2800[18]
# 16  1500
# 17  70
# 18  300
# 19  1790 (2019)[21]
# 20  4200 (2021)     7010[23]
# 21  4115[25]
# 22  200
# 23  30
# 24  50
# 25  150
# 26  20
# 27  60
# 28  400
# 29  800
# 30  20
# ⋮   ⋮               ⋮
# 525 30
# 526 20              Closed[334]
# 527 100
# 528 1700
# 529 350
# 530
# 531 1000
# 532 400+
# 533 1833
# 534 20000           65000
# 535 100
# 536 35
# 537 1400
# 538 500
# 539 500
# 540 1000
# 541 1000
# 542 100
# 543 600
# 544 1800
# 545
# 546 7000
# 547 500
# 548 16
# 549 500
# 550 40
# 551
# 552                 457 (May 2022)[364]
# 553 300
# 554 5,400

# %% [markdown]
# Summarize the bike sharing system data frame

# %%
# Summarize the dataframe
summary(df)
# Out:
#    Country              City               Name              System
#  Length:554         Length:554         Length:554         Length:554
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#    Operator           Launched         Discontinued         Stations
#  Length:554         Length:554         Length:554         Length:554
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#    Bicycles         Daily ridership
#  Length:554         Length:554
#  Class :character   Class :character
#  Mode  :character   Mode  :character

# %% [markdown]
# Export the data frame as a csv file called `raw_bike_sharing_systems.csv`

# %%
# Export the dataframe into a csv file
write.csv(df, "raw_bike_sharing_systems.csv")

# %% [markdown]
# For more details about webscraping with `rvest`, please refer to the previous webscraping notebook here:
#
# [Webscraping in R](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0101EN-Coursera/v2/M4_Working_With_Data/lab3_jupyter_webscraping.ipynb)

# %% [markdown]
# ## Authors
#
# <a href="https://www.linkedin.com/in/yan-luo-96288783/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork878-2022-01-01" target="_blank">Yan Luo</a>

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description           |
# | ----------------- | ------- | ---------- | ---------------------------- |
# | 2021-04-05        | 0.1     | Yan        | Initial version created      |
# |                   |         |            |                              |
# |                   |         |            |                              |
#
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
