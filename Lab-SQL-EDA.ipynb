# %% [markdown]
# <center>
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0321EN-SkillsNetwork/labs/module_1/images/SN_web_lightmode.png" width="300">
# </center>
#
# # Assignment: Exploratory Data Analysis with SQL
# Estimated time needed: 60 minutes
#
#
# # Introduction
# Using this R notebook you will perform exploratory data analysis tasks using SQL queries with the RODBC R package. You will not be graded here, but you will be asked to present some of these results in your final assignment, where you will be graded on the accuracy of your results as well as the content of your SQL queries.

# %% [markdown]
# ### Establish your Db2 connection
# Load the 'RODBC' library, and use the 'odbcConnect( )' function as you did in the previous lab to establish the connection to your Db2 assets.
# Provided you successfully loaded your data into the tables in that lab, you are now ready to start running SQL queries using the RODBC library as you did in Course 3.

# %%
# provide your solution here
path = "ds/seoul_bike_sharing.csv"
ds <- read.csv(path)
ds
# Out:
#      DATE       RENTED_BIKE_COUNT HOUR TEMPERATURE HUMIDITY WIND_SPEED
# 1    01/12/2017 254                0   -5.2        37       2.2
# 2    01/12/2017 204                1   -5.5        38       0.8
# 3    01/12/2017 173                2   -6.0        39       1.0
# 4    01/12/2017 107                3   -6.2        40       0.9
# 5    01/12/2017  78                4   -6.0        36       2.3
# 6    01/12/2017 100                5   -6.4        37       1.5
# 7    01/12/2017 181                6   -6.6        35       1.3
# 8    01/12/2017 460                7   -7.4        38       0.9
# 9    01/12/2017 930                8   -7.6        37       1.1
# 10   01/12/2017 490                9   -6.5        27       0.5
# 11   01/12/2017 339               10   -3.5        24       1.2
# 12   01/12/2017 360               11   -0.5        21       1.3
# 13   01/12/2017 449               12    1.7        23       1.4
# 14   01/12/2017 451               13    2.4        25       1.6
# ...

# %% [markdown]
# ## Task 1 - Record Count
# #### Determine how many records are in the seoul_bike_sharing dataset.

# %% [markdown]
# ### Solution 1

# %%
# provide your solution here
dim(ds)
# Out:
# [1] 8465   14

# %% [markdown]
# ## Task 2 - Operational Hours
# #### Determine how many hours had non-zero rented bike count.

# %% [markdown]
# ### Solution 2

# %%
# provide your solution here
library('tidyverse')
ds %>% filter(RENTED_BIKE_COUNT != 0) %>% summarise(total = sum(HOUR))
# Out:
#   total
# 1 97407

# %% [markdown]
# ## Task 3 - Weather Outlook
# #### Query the the weather forecast for Seoul over the next 3 hours.
# Recall that the records in the CITIES_WEATHER_FORECAST dataset are 3 hours apart, so we just need the first record from the query.

# %% [markdown]
# ### Solution 3

# %%
# provide your solution here
path = "ds/cities_weather_forecast.csv"
ds <- read.csv(path)
ds %>% mutate(date = as.Date(FORECAST_DATETIME, format = "%Y-%m-%d")) %>% filter(year(date) > max(year(date))-1)
# Out:
#     CITY   WEATHER VISIBILITY TEMP  TEMP_MIN TEMP_MAX PRESSURE HUMIDITY
# 1   Seoul  Clear   10000      12.32 10.91    12.32    1015     50
# 2   Seoul  Clear   10000      11.48  9.81    11.48    1016     48
# 3   Seoul  Clouds  10000       9.99  8.82     9.99    1015     46
# 4   Seoul  Clouds  10000       7.87  7.87     7.87    1014     46
# 5   Seoul  Clouds  10000      10.09 10.09    10.09    1014     37
# 6   Seoul  Rain    10000       9.74  9.74     9.74    1014     48
# 7   Seoul  Clouds  10000      11.39 11.39    11.39    1012     44
# 8   Seoul  Rain    10000       9.75  9.75     9.75    1012     57
# 9   Seoul  Rain    10000       9.11  9.11     9.11    1013     51
# 10  Seoul  Clear   10000       8.33  8.33     8.33    1013     62
# 11  Seoul  Clear   10000       7.57  7.57     7.57    1013     69
# 12  Seoul  Clear   10000       7.13  7.13     7.13    1014     65
# 13  Seoul  Clear   10000      10.49 10.49    10.49    1015     45
# ...

# %% [markdown]
# ## Task 4 - Seasons
# #### Find which seasons are included in the seoul bike sharing dataset.

# %% [markdown]
# ### Solution 4

# %%
# provide your solution here
ds %>% distinct(SEASONS)
# Out:
#   SEASONS
# 1 Winter
# 2 Spring
# 3 Summer
# 4 Autumn

# %% [markdown]
# ## Task 5 - Date Range
# #### Find the first and last dates in the Seoul Bike Sharing dataset.

# %% [markdown]
# ### Solution 5

# %%
# provide your solution here
ds %>% mutate(DATE1 = as.Date(DATE, format = "%d/%m/%Y")) %>% summarise(mi = min(DATE1), ma = max(DATE1))
# Out:
#   mi         ma
# 1 2017-12-01 2018-11-30

# %% [markdown]
# ## Task 6 - Subquery - 'all-time high'
# #### determine which date and hour had the most bike rentals.

# %% [markdown]
# ### Solution 6

# %%
# provide your solution here
ds %>% filter(RENTED_BIKE_COUNT == max(RENTED_BIKE_COUNT))
# Out:
#   DATE       RENTED_BIKE_COUNT HOUR TEMPERATURE HUMIDITY WIND_SPEED VISIBILITY
# 1 19/06/2018 3556              18   24.1        57       2.9        1301
#   DEW_POINT_TEMPERATURE SOLAR_RADIATION RAINFALL SNOWFALL SEASONS HOLIDAY
# 1 15                    0.56            0        0        Summer  No Holiday
#   FUNCTIONING_DAY
# 1 Yes

# %% [markdown]
# ## Task 7 - Hourly popularity and temperature by season
# #### Determine the average hourly temperature and the average number of bike rentals per hour over each season. List the top ten results by average bike count.

# %% [markdown]
# ### Solution 7

# %%
# provide your solution here
ds <- ds %>% mutate(DATE = as.Date(DATE, format = "%d/%m/%Y"))
ds %>% group_by(HOUR, SEASONS) %>% summarise(avg_temp = mean(TEMPERATURE), avg_bike = mean(RENTED_BIKE_COUNT), .groups='drop') %>% arrange(desc(avg_bike)) %>%
slice(1:10)
# Out:
#    HOUR SEASONS avg_temp avg_bike
# 1  18   Summer  29.38791 2135.141
# 2  18   Autumn  16.03185 1983.333
# 3  19   Summer  28.27378 1889.250
# 4  20   Summer  27.06630 1801.924
# 5  21   Summer  26.27826 1754.065
# 6  18   Spring  15.97222 1689.311
# 7  22   Summer  25.69891 1567.870
# 8  17   Autumn  17.27778 1562.877
# 9  17   Summer  30.07691 1526.293
# 10 19   Autumn  15.06346 1515.568

# %% [markdown]
# ## Task 8 - Rental Seasonality
# #### Find the average hourly bike count during each season.
# Also include the minimum, maximum, and standard deviation of the hourly bike count for each season.

# %% [markdown]
# ### Solution 8

# %%
# provide your solution here
ds %>% group_by(SEASONS, HOUR) %>% summarise(hourly_bike_count = sum(RENTED_BIKE_COUNT), .groups='drop') %>% group_by(SEASONS) %>%
summarise(mi = min(hourly_bike_count), ma = max(hourly_bike_count), std = sd(hourly_bike_count))
# Out:
#   SEASONS mi    ma     std
# 1 Autumn  13073 160650 38134.586
# 2 Spring   9740 152038 37029.662
# 3 Summer  20591 196433 48842.050
# 4 Winter   4543  39447  9372.557

# %% [markdown]
# Let's explore a bit and see what might be the most significant contributing factors in terms of the provided data.

# %% [markdown]
# ## Task 9 - Weather Seasonality
# #### Consider the weather over each season. On average, what were the TEMPERATURE, HUMIDITY, WIND_SPEED, VISIBILITY, DEW_POINT_TEMPERATURE, SOLAR_RADIATION, RAINFALL, and SNOWFALL per season?
# Include the average bike count as well , and rank the results by average bike count so you can see if it is correlated with the weather at all.

# %%
ds2
# Out:
#        SEASONS CITY   WEATHER VISIBILITY.x TEMP  TEMP_MIN TEMP_MAX PRESSURE
# 1      Spring  Seoul  Clear   10000        12.32 10.91    12.32    1015
# 2      Spring  Seoul  Clear   10000        12.32 10.91    12.32    1015
# 3      Spring  Seoul  Clear   10000        12.32 10.91    12.32    1015
# 4      Spring  Seoul  Clear   10000        12.32 10.91    12.32    1015
# 5      Spring  Seoul  Clear   10000        12.32 10.91    12.32    1015
# 6      Spring  Seoul  Clear   10000        12.32 10.91    12.32    1015
# 7      Spring  Seoul  Clear   10000        12.32 10.91    12.32    1015
# 8      Spring  Seoul  Clear   10000        12.32 10.91    12.32    1015
# 9      Spring  Seoul  Clear   10000        12.32 10.91    12.32    1015
# 10     Spring  Seoul  Clear   10000        12.32 10.91    12.32    1015
# 11     Spring  Seoul  Clear   10000        12.32 10.91    12.32    1015
# 12     Spring  Seoul  Clear   10000        12.32 10.91    12.32    1015
# ...

# %% [markdown]
# ### Solution 9

# %%
query <- 
# provide your solution here

# %% [markdown]
# ## Task 10 - Total Bike Count and City Info for Seoul
# #### Use an implicit join across the WORLD_CITIES and the BIKE_SHARING_SYSTEMS tables to determine the total number of bikes avaialble in Seoul, plus the following city information about Seoul: CITY, COUNTRY, LAT, LON, POPULATION, in a single view.
# Notice that in this case, the CITY column will work for the WORLD_CITIES table, but in general you would have to use the CITY_ASCII column.

# %% [markdown]
# ### Solution 10

# %%
# provide your solution here
wc <- read.csv("ds/world_cities.csv")
bss <- read.csv("ds/bike_sharing_systems.csv")
 
ds3 <- merge(wc, bss, by="CITY")
ds3 %>% filter(CITY == 'Seoul')%>% select(CITY, COUNTRY.x, LAT, LNG, POPULATION)
# Out:
#   CITY  COUNTRY.x    LAT     LNG POPULATION
# 1 Seoul Korea, South 37.5833 127 21794000

# %% [markdown]
# ## Task 11 - Find all city names and coordinates with comparable bike scale to Seoul's bike sharing system
# #### Find all cities with total bike counts between 15000 and 20000. Return the city and country names, plus the coordinates (LAT, LNG), population, and number of bicycles for each city.
# Later we will ask you to visualize these similar cities on leaflet, with some weather data.

# %% [markdown]
# ### Solution 11

# %%
d1 <- read.csv("ds/bike_sharing_systems.csv")
d2 <- read.csv("ds/cities_weather_forecast.csv")
d3 <- read.csv("ds/seoul_bike_sharing.csv")
d4 <- read.csv("ds/world_cities.csv")

# %%
v <- d1 %>% filter(BICYCLES > 15000 & BICYCLES < 20000)

# %%
merge(v, d4, by='CITY') %>% select(CITY, COUNTRY.x, LAT, LNG, POPULATION, BICYCLES)
# Out:
#   CITY     COUNTRY.x LAT     LNG      POPULATION BICYCLES
# 1 Beijing  China     39.9050 116.3914 19433000   16000
# 2 Shanghai China     31.1667 121.4667 22120000   19165

# %%
close(conn)

# %% [markdown]
# ## Author(s)
#
# <h4> Jeff Grossman </h4>
#
# ## Contributor(s)
#
# <h4> Yan Luo, Rav Ahuja </h4>
#
# ## Change log
#
# | Date       | Version | Changed by    | Change Description                                                                |
# | ---------- | ------- | ------------- | --------------------------------------------------------------------------------- |
# | 2021-05-04 | 0.2     | Jeff Grossman | Finalize                               |
# | 2021-04-22 | 0.2     | Jeff Grossman | Update as per peer review                               |
# | 2021-04-10 | 0.2     | Jeff Grossman | Add data sources and implicit joins                                  |
# | 2021-04-05 | 0.1     | Jeff Grossman | Start content creation                                                          |
#
#
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
